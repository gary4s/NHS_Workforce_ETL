-- %%
--DROP TABLE IF EXISTS nhs_bronze_workforce;
--DROP TABLE IF EXISTS nhs_silver_workforce;


--CREATE TABLE nhs_silver_workforce (
--    PERIOD VARCHAR(255),                  
--   TYPE VARCHAR(255),
--    NHSE_REGION_CODE VARCHAR(255),
--   NHSE_REGION_NAME VARCHAR(255),
--    ICS_CODE VARCHAR(255),
--    ICS_NAME VARCHAR(255),
--    REPORTING_ORG_NAME VARCHAR(255),
--    REPORTING_ORG_CODE VARCHAR(255),
--    CLUSTER_GROUP VARCHAR(255),
--    BENCHMARK_GROUP VARCHAR(255),
--    STAFF_GROUP_1_NAME VARCHAR(255),
--   HC VARCHAR(255),
--    FTE VARCHAR(255),
--    ingested_at TIMESTAMP
--);

--delete from nhs_bronze_workforce;
--delete from nhs_silver_workforce;


--select count(*) as bronze_count
--from nhs_bronze_workforce;

--select *
-- from nhs_bronze_workforce
--limit 10;

--select count(*) as silver_count
--from nhs_silver_workforce;


--select *
--from nhs_silver_workforce
--limit 10;

--select count(*) as gold_count
-- from nhs_gold_StaffGroup_summary;

select *
 from nhs_gold_StaffGroup_summary
limit 10;

select *
 from nhs_gold_summary
limit 10;

select *
 from gold_regional_summary
limit 10;
