# %%
from pyspark.sql.functions import col, trim

#load ata from bronze table
bronze_df = spark.table("nhs_bronze_workforce")

#apply transformations
silver_df = (bronze_df
             #trim any whotespace
             .withColumn("OrgCode", trim(col("OrgCode")))
             .withColumn("StaffGroup", trim(col("StaffGroup")))
             
             #cast to numeric types
             .withColumn("HC", col("HC").cast("integer"))
             .withColumn("FTE", col("FTE").cast("double"))
             
             #filter out rows where OrgCode is null
             .filter(col("OrgCode").isNotNull())
            
             )

#display(bronze_df.head(10))
#display(silver_df.head(10))

# Append to Silver Table
silver_df.write.format("delta").mode("overwrite").saveAsTable("nhs_silver_workforce")

# 4. Verify the Schema
silver_df.printSchema()
