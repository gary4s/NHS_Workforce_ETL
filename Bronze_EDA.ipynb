# %%
# 1. Define the path (Update this to match your actual Volume and File name)
volume_path = "/Volumes/workspace/default/nhs_workforce/Monthly turnover from organisation benchmarking source data, November 2023.csv"

# 2. Read the CSV
df = (spark.read
      .format("csv")
      .option("header", "true")
      .option("inferSchema", "true") # This automatically detects if FTE is a number
      .load(volume_path))

# 3. View the data
display(df.head(10))
